# %%
from etl.users import *
from etl.transactions import *
from lib.constants import *
from lib.sql import *
from analysis.viz import *
from analysis.user_paths import *
from analysis.subscription_opp import *

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
users = get_users()
# Out:
#   sql_to_df (/home/jovyan/lib/sql.py:19):
#     1.950 seconds
#
#
#   _join_mixpanel_stats (/home/jovyan/etl/users.py:145):
#     3.971 seconds
#
#
#   sql_to_df (/home/jovyan/lib/sql.py:19):
#     0.229 seconds
#
#
#   _join_first_order_facts (/home/jovyan/etl/users.py:169):
#     1.456 seconds
#
#
#   _join_user_list (/home/jovyan/etl/users.py:65):
#     0.461 seconds
#
#
#   _join_user_list (/home/jovyan/etl/users.py:65):
#     0.296 seconds
#
#
#   _join_user_list (/home/jovyan/etl/users.py:65):
#     0.786 seconds
#
#
#   _cast_fields (/home/jovyan/etl/users.py:87):
#     12.157 seconds
#
#
#   get_users (/home/jovyan/etl/users.py:14):
#     21.785 seconds

# %%
orders_per_year(users)
# Out:
# count   487,389.0000
# mean          1.5235
# std           1.2347
# min           0.2615
# 10%           1.0000
# 20%           1.0000
# 30%           1.0000
# 40%           1.0000
# 50%           1.0000
# 60%           1.0000
# 70%           1.0443
# 80%           2.0000
# 90%           3.0000
# 95%           3.9860
# max          48.2987
# Name: orders_per_year, dtype: float64

# %%
max(1,2)
# Out:
# [autoreload of analysis.subscription_opp failed: Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 246, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/conda/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 369, in superreload
#     module = reload(module)
#   File "/opt/conda/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/opt/conda/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/jovyan/analysis/subscription_opp.py", line 30
#     def subscription_op_size(users: pd.DataFrame)
#                                                 ^
# SyntaxError: invalid syntax
# ]
# 2

# %%
subscription_op_size(users)
