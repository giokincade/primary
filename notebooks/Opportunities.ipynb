# %%
from etl.users import *
from etl.transactions import *
from lib.constants import *
from lib.sql import *
from analysis.viz import *
from analysis.user_paths import *
from analysis.opportunity import *

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
start = date(2019, 1, 1)
end = date(2019, 2, 25)
sql_to_df("conversions_per_page.sql", start=start, end=end)
# Out:
#   sql_to_df (/home/jovyan/lib/sql.py:16):
#     25.047 seconds
#              event               segment avg_daily_users  \
# 0              bag             all_users        3539.357
# 1              bag  no_prior_transaction        2481.517
# 2              bag     prior_transaction        1057.839
# 3         checkout             all_users        1088.500
# 4         checkout  no_prior_transaction         493.267
# 5         checkout     prior_transaction         595.232
# 6   checkout_start             all_users        1598.625
# 7   checkout_start  no_prior_transaction         862.660
# 8   checkout_start     prior_transaction         735.964
# 9             home             all_users        6026.982
# 10            home  no_prior_transaction        4542.000
# 11            home     prior_transaction        1484.982
# 12         product             all_users       12159.785
# 13         product  no_prior_transaction        9886.303
# ...

# %%
sql_to_df("daily_events.sql", start=start, end=end)
# Out:
#   sql_to_df (/home/jovyan/lib/sql.py:16):
#     3.813 seconds
#             event avg_daily_users
# 0             bag        3539.357
# 1        checkout        1088.500
# 2  checkout_start        1598.625
# 3            home        6026.982
# 4           other       18586.321
# 5         product       12159.785
# 6    product_list       10044.732

# %%
opps = opportunity_sizes()
# Out:
#   sql_to_df (/home/jovyan/lib/sql.py:16):
#     0.016 seconds
# <h1>Event + Segment Data</h1>
#              event                                 segment  avg_daily_users  \
# 0              bag                               all_users         3722.816
# 1              bag                    no_prior_transaction         2606.804
# 2              bag                       prior_transaction         1116.011
# 3         checkout                               all_users         1193.804
# 4         checkout                    no_prior_transaction          550.965
# 5         checkout                       prior_transaction          642.839
# 6   checkout_start                               all_users         1745.114
# 7   checkout_start                    no_prior_transaction          946.770
# 8   checkout_start                       prior_transaction          798.344
# 9             home                               all_users         6296.712
# ...

# %%
opps.to_csv(DATA_DIR + "opps.csv")
